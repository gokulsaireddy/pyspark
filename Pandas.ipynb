# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series -- one dimensional, has index for each element
# Dataframe -- collection of series ( column wise )

# %%
df = pd.read_csv(filepath_or_buffer='./Downloads/ExerciseFiles/data/olympics.csv',skiprows=4)

# %%
df
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
df.shape
df.info()
# Out:
# (29216, 10)

# %%
testing = pd.Series([1,2,3,4,4,None,np.nan])
#df['City'].value_counts()
testing.value_counts(dropna=False)
# Out:
# 4.0    2
# NaN    2
# 1.0    1
# 2.0    1
# 3.0    1
# dtype: int64

# %%
df['Sport'].sort_index()   # sorts by index 
df['Sport'].sort_values()  # sorts by values
# Out:
# 0         Aquatics
# 1         Aquatics
# 2         Aquatics
# 3         Aquatics
# 4         Aquatics
#            ...
# 29211    Wrestling
# 29212    Wrestling
# 29213    Wrestling
# 29214    Wrestling
# 29215    Wrestling
# Name: Sport, Length: 29216, dtype: object

# %%
# Boolean indexing
df[['City','Sport']][df['City']=='Beijing']
# Out:
#           City      Sport
# 27174  Beijing   Aquatics
# 27175  Beijing   Aquatics
# 27176  Beijing   Aquatics
# 27177  Beijing   Aquatics
# 27178  Beijing   Aquatics
# ...        ...        ...
# 29211  Beijing  Wrestling
# 29212  Beijing  Wrestling
# 29213  Beijing  Wrestling
# 29214  Beijing  Wrestling
# 29215  Beijing  Wrestling
#
# [2042 rows x 2 columns]

# %%
# String handling with series
df[df['City'].str.startswith('Bei')]
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
# Index

df.index[1]
# Out:
# 1

# %%
new_df=df.set_index('City')
new_df
# Out:
#          Edition      Sport       Discipline               Athlete  NOC  \
# City
# Athens      1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# Athens      1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# Athens      1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# Athens      1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# Athens      1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...          ...        ...              ...                   ...  ...
# Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
#         Gender                       Event Event_gender   Medal
# City
# ...

# %%
# loc[row label/s,col label/s]   more info ... shift+tab
new_df.loc['Athens']
new_df
# Out:
#          Edition      Sport       Discipline               Athlete  NOC  \
# City
# Athens      1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# Athens      1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# Athens      1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# Athens      1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# Athens      1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...          ...        ...              ...                   ...  ...
# Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
#         Gender                       Event Event_gender   Medal
# City
# ...

# %%
# iloc : Gives rows by integer bases indexing
new_df.iloc[0]
# Out:
# Edition                   1896
# Sport                 Aquatics
# Discipline            Swimming
# Athlete          HAJOS, Alfred
# NOC                        HUN
# Gender                     Men
# Event           100m freestyle
# Event_gender                 M
# Medal                     Gold
# Name: Athens, dtype: object

# %%
# Groupby

gender_group_by= new_df.groupby('Gender')
for i,j in gender_group_by:
    print(type(i))
    print(type(j))
# Out:
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'str'>
# <class 'pandas.core.frame.DataFrame'>

# %%
res = df.groupby('Gender')
for i,j in res:
    print(i)
    print(j)
# Out:
# Men
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
res.agg(['count'])
# Out:
#          City Edition  Sport Discipline Athlete    NOC  Event Event_gender  \
#         count   count  count      count   count  count  count        count
# Gender
# Men     21721   21721  21721      21721   21721  21721  21721        21721
# Women    7495    7495   7495       7495    7495   7495   7495         7495
#
#         Medal
#         count
# Gender
# Men     21721
# Women    7495
